# %% [markdown]
# # merging titles and  talent

# %%
# import the packages that will be used in this project

import pandas as pd
import requests as rq
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# setting pandas display to avoid scientific notation in my dataframes
pd.options.display.float_format = '{:.2f}'.format
    # - code generously donated by Dianne Tunnicliffe 
    # https://github.com/dtunnicliffe/movie-analysis-project/blob/project/microsoft_movie_analysis.ipynb

# %%
# read in the data from IMDB

# Two datafiles will be used here: (1) imdb.title.basics.csv.gz, and (2) imdb.title.ratings.csv.gz
names_by_id = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
title_and_genre = pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
directors_and_writers = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
talent_list = pd.read_csv('data/zippedData/imdb.title.principals.csv.gz')
popularity_and_votes = pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
budget_and_gross = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz')

# %%
# Lets merge all dataframes that have a common key (these will be the IMDB dataframes with 'tconst')
imdb_titles_merged_df = title_and_genre.merge(
    directors_and_writers, on='tconst').merge(
    talent_list, on='tconst')

imdb_titles_merged_df.head(10)
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 1  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 2  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 3  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 4  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 5  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 6  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 7  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 8  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 9  tt0063540     Sunghursh      Sunghursh        2013           175.00
#
#                genres  directors                                  writers  \
# 0  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 1  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 2  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 3  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 4  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 5  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 6  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 7  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 8  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 9  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
#
#    ordering     nconst  category         job                       characters
# 0        10  nm0006210  composer         NaN                              NaN
# 1         1  nm0474801     actor         NaN  ["Kundan S. Prasad","Bajrangi"]
# 2         2  nm0904537   actress         NaN      ["Munni","Laila-E-Aasmaan"]
# 3         3  nm0756379     actor         NaN            ["Ganeshi N. Prasad"]
# 4         4  nm0474876     actor         NaN             ["Dwarka N. Prasad"]
# 5         5  nm0712540  director         NaN                              NaN
# 6         6  nm0023551    writer    dialogue                              NaN
# 7         7  nm1194313    writer       story                              NaN
# 8         8  nm0347899    writer    dialogue                              NaN
# 9         9  nm1391276    writer  screenplay                              NaN

# %%
# # Lets clean this up and drop columns we don't need. We will keep job because it may tell us who the primary writer is
# imdb_titles_merged_df.drop(['original_title', 'start_year','runtime_minutes'], axis=1, inplace=True)

# # and check the dataframe
# imdb_titles_merged_df.head()

# %%
# Now we begin merging the other dataframes
# We'll begin with the names_by_id dataframe and merge on the 'nconst' key
imdb_titles_merged_df = imdb_titles_merged_df.merge(names_by_id, on='nconst')

# and check the resulting dataframe
imdb_titles_merged_df.head()
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 1  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 2  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 3  tt0063540     Sunghursh      Sunghursh        2013           175.00
# 4  tt0063540     Sunghursh      Sunghursh        2013           175.00
#
#                genres  directors                                  writers  \
# 0  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 1  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 2  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 3  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
# 4  Action,Crime,Drama  nm0712540  nm0023551,nm1194313,nm0347899,nm1391276
#
#    ordering     nconst  category  job                       characters  \
# 0        10  nm0006210  composer  NaN                              NaN
# 1         1  nm0474801     actor  NaN  ["Kundan S. Prasad","Bajrangi"]
# 2         2  nm0904537   actress  NaN      ["Munni","Laila-E-Aasmaan"]
# 3         3  nm0756379     actor  NaN            ["Ganeshi N. Prasad"]
# 4         4  nm0474876     actor  NaN             ["Dwarka N. Prasad"]
#
#      primary_name  birth_year  death_year  \
# 0         Naushad     1919.00     2006.00
# 1     Dilip Kumar     1922.00         nan
# 2  Vyjayanthimala     1933.00         nan
# 3    Balraj Sahni     1913.00     1973.00
# 4   Sanjeev Kumar     1938.00     1985.00
#
#                        primary_profession  \
# 0    composer,soundtrack,music_department
# 1                   actor,writer,director
# 2  actress,music_department,miscellaneous
# 3                   actor,writer,director
# 4                                   actor
#
#                           known_for_titles
# 0  tt0054910,tt0266765,tt0044392,tt0053999
# 1  tt0058287,tt0054910,tt0047990,tt0084667
# 2  tt0047990,tt0054910,tt0050665,tt0058547
# 3  tt0055039,tt0043307,tt0234827,tt0233326
# 4  tt0148841,tt0215517,tt0073707,tt0178186

# %%
# Next lets merge the popularity_and_votes dataframe with a "right" merge, since we only want to keep titles that have a popularity score and votes
# We see the common key is 'original_title' so we will merge on this
imdb_titles_merged_df = imdb_titles_merged_df.merge(popularity_and_votes, on='original_title', how='right')

# and check the resulting dataframe
imdb_titles_merged_df.head()
# Out:
#       tconst                                 primary_title  \
# 0  tt0926084  Harry Potter and the Deathly Hallows: Part 1
# 1  tt0926084  Harry Potter and the Deathly Hallows: Part 1
# 2  tt0926084  Harry Potter and the Deathly Hallows: Part 1
# 3  tt0926084  Harry Potter and the Deathly Hallows: Part 1
# 4  tt0926084  Harry Potter and the Deathly Hallows: Part 1
#
#                                  original_title  start_year  runtime_minutes  \
# 0  Harry Potter and the Deathly Hallows: Part 1     2010.00           146.00
# 1  Harry Potter and the Deathly Hallows: Part 1     2010.00           146.00
# 2  Harry Potter and the Deathly Hallows: Part 1     2010.00           146.00
# 3  Harry Potter and the Deathly Hallows: Part 1     2010.00           146.00
# 4  Harry Potter and the Deathly Hallows: Part 1     2010.00           146.00
#
#                       genres  directors              writers  ordering  \
# 0  Adventure,Fantasy,Mystery  nm0946734  nm0460141,nm0746830     10.00
# 1  Adventure,Fantasy,Mystery  nm0946734  nm0460141,nm0746830      5.00
# 2  Adventure,Fantasy,Mystery  nm0946734  nm0460141,nm0746830      8.00
# 3  Adventure,Fantasy,Mystery  nm0946734  nm0460141,nm0746830      1.00
# 4  Adventure,Fantasy,Mystery  nm0946734  nm0460141,nm0746830      2.00
#
#       nconst  ...                         known_for_titles Unnamed: 0  \
# 0  nm0006035  ...  tt1504320,tt0436697,tt1024648,tt2431286          0
# 1  nm0946734  ...  tt0918940,tt0373889,tt1201607,tt0926084          0
# 2  nm0057655  ...  tt1201607,tt0330373,tt0417741,tt0926084          0
# 3  nm0705356  ...  tt1528071,tt0926084,tt1201607,tt4034354          0
# 4  nm0914612  ...  tt0241527,tt2132285,tt1659337,tt2771200          0
#
#          genre_ids     id  original_language  popularity release_date  \
# 0  [12, 14, 10751]  12444                 en       33.53   2010-11-19
# 1  [12, 14, 10751]  12444                 en       33.53   2010-11-19
# 2  [12, 14, 10751]  12444                 en       33.53   2010-11-19
# 3  [12, 14, 10751]  12444                 en       33.53   2010-11-19
# 4  [12, 14, 10751]  12444                 en       33.53   2010-11-19
#
#                                           title  vote_average vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1          7.70      10788
# 1  Harry Potter and the Deathly Hallows: Part 1          7.70      10788
# 2  Harry Potter and the Deathly Hallows: Part 1          7.70      10788
# 3  Harry Potter and the Deathly Hallows: Part 1          7.70      10788
# 4  Harry Potter and the Deathly Hallows: Part 1          7.70      10788
#
# [5 rows x 27 columns]

# %%
# Lastly we will merge in the financials datafame, budget_and_gross, however we do not have a common key
# We see the dataframe has a key 'movie' which is the same as 'original_title' so we will change the column name to match
budget_and_gross.rename({'movie':'original_title'}, axis=1, inplace=True)
                         
# and check it
budget_and_gross.head()
# Out:
#    id  release_date                               original_title  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Now lets merge it. We will do another right join to keep only titles with financial info
imdb_titles_merged_df = imdb_titles_merged_df.merge(budget_and_gross, on='original_title', how='right')

# and check it
imdb_titles_merged_df.head()
# Out:
#       tconst                                primary_title  \
# 0        NaN                                          NaN
# 1  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 2  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 3  tt1298650  Pirates of the Caribbean: On Stranger Tides
# 4  tt1298650  Pirates of the Caribbean: On Stranger Tides
#
#                                 original_title  start_year  runtime_minutes  \
# 0                                       Avatar         nan              nan
# 1  Pirates of the Caribbean: On Stranger Tides     2011.00           136.00
# 2  Pirates of the Caribbean: On Stranger Tides     2011.00           136.00
# 3  Pirates of the Caribbean: On Stranger Tides     2011.00           136.00
# 4  Pirates of the Caribbean: On Stranger Tides     2011.00           136.00
#
#                      genres  directors  \
# 0                       NaN        NaN
# 1  Action,Adventure,Fantasy  nm0551128
# 2  Action,Adventure,Fantasy  nm0551128
# 3  Action,Adventure,Fantasy  nm0551128
# 4  Action,Adventure,Fantasy  nm0551128
#
#                                              writers  ordering     nconst  \
# 0                                                NaN       nan        NaN
# 1  nm0254645,nm0744429,nm0064181,nm0938684,nm0694627      1.00  nm0000136
# 2  nm0254645,nm0744429,nm0064181,nm0938684,nm0694627      8.00  nm0064181
# 3  nm0254645,nm0744429,nm0064181,nm0938684,nm0694627      4.00  nm0001691
# 4  nm0254645,nm0744429,nm0064181,nm0938684,nm0694627      3.00  nm0574534
#
#    ... popularity release_date_x                                        title  \
# 0  ...      26.53     2009-12-18                                       Avatar
# 1  ...      30.58     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2  ...      30.58     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3  ...      30.58     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 4  ...      30.58     2011-05-20  Pirates of the Caribbean: On Stranger Tides
#
#   vote_average  vote_count  id_y release_date_y production_budget  \
# 0         7.40    18676.00     1   Dec 18, 2009      $425,000,000
# 1         6.40     8571.00     2   May 20, 2011      $410,600,000
# 2         6.40     8571.00     2   May 20, 2011      $410,600,000
# 3         6.40     8571.00     2   May 20, 2011      $410,600,000
# 4         6.40     8571.00     2   May 20, 2011      $410,600,000
#
#    domestic_gross worldwide_gross
# 0    $760,507,625  $2,776,345,279
# 1    $241,063,875  $1,045,663,875
# 2    $241,063,875  $1,045,663,875
# 3    $241,063,875  $1,045,663,875
# 4    $241,063,875  $1,045,663,875
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Let's start our analysis
# ### We are looking to draw inferences on
# * a movies popularity,
# * its budget and gross,
# * and talent attached to popular and profitable movies
#
# #### Some assumptions we can draw on the data:
# 1. The talent_list dataframe contains an ordering column with several different names attachd to the project, lets assume that the first entry (order value of 1) is the lead actor/actress
#
# 2. For simplicity's sake we will only focus on domestic gross

# %%
# Lets pull a table with movies and their popularity, budget and gross
# Lets check our keys and pull a table with only the keys were are interested in here, i.e. drop the rest

# checking keys:
imdb_titles_merged_df.info()

#we see that some
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36923 entries, 0 to 36922
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tconst              32942 non-null  object
#  1   primary_title       32942 non-null  object
#  2   original_title      36923 non-null  object
#  3   start_year          32942 non-null  float64
#  4   runtime_minutes     30519 non-null  float64
#  5   genres              32732 non-null  object
#  6   directors           32773 non-null  object
#  7   writers             31185 non-null  object
#  8   ordering            32942 non-null  float64
#  9   nconst              32942 non-null  object
#  10  category            32942 non-null  object
#  11  job                 10260 non-null  object
#  12  characters          13329 non-null  object
#  13  primary_name        32942 non-null  object
#  14  birth_year          15656 non-null  float64
#  15  death_year          615 non-null    float64
#  16  primary_profession  32312 non-null  object
#  17  known_for_titles    32555 non-null  object
#  18  Unnamed: 0          33100 non-null  float64
#  19  genre_ids           33100 non-null  object
#  20  id_x                33100 non-null  float64
#  21  original_language   33100 non-null  object
#  22  popularity          33100 non-null  float64
#  23  release_date_x      33100 non-null  object
#  24  title               33100 non-null  object
#  25  vote_average        33100 non-null  float64
#  26  vote_count          33100 non-null  float64
#  27  id_y                36923 non-null  int64
#  28  release_date_y      36923 non-null  object
#  29  production_budget   36923 non-null  object
#  30  domestic_gross      36923 non-null  object
#  31  worldwide_gross     36923 non-null  object
# dtypes: float64(10), int64(1), object(21)
# memory usage: 9.3+ MB

# %% [markdown]
# ### For our analysis we want to focus on movies in the modern era as movies from 20 years ago have lower budgets and the technology is not comparable to today
# #### Lets filter out titles that were made before the year 2000
# #### We see from the info that 'start_year' is of type float, which will make filtering easier that converting to datetime

# %%
imdb_titles_merged_df = imdb_titles_merged_df[imdb_titles_merged_df['start_year'] >= 2010.00]

imdb_titles_merged_df['start_year'].min()
# Out:
# 2010.0

# %%
# Lets pull a table with columns:
# ['original_title', 'popularity' 'vote_average', 'vote_count', 'production_budget', and 'domestic_gross']

popularity_and_budget = imdb_titles_merged_df[['original_title', 'popularity', 'vote_average', 'vote_count', 'production_budget', 'domestic_gross']]

# lets check it
popularity_and_budget.head(50)
# Out:
#                                  original_title  popularity  vote_average  \
# 1   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 2   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 3   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 4   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 5   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 6   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 7   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 8   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 9   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 10  Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 12                      Avengers: Age of Ultron       44.38          7.30
# 13                      Avengers: Age of Ultron       44.38          7.30
# 14                      Avengers: Age of Ultron       44.38          7.30
# 15                      Avengers: Age of Ultron       44.38          7.30
# 16                      Avengers: Age of Ultron       44.38          7.30
# 17                      Avengers: Age of Ultron       44.38          7.30
# 18                      Avengers: Age of Ultron       44.38          7.30
# 19                      Avengers: Age of Ultron       44.38          7.30
# 20                      Avengers: Age of Ultron       44.38          7.30
# 21                      Avengers: Age of Ultron       44.38          7.30
# 24                       Avengers: Infinity War       80.77          8.30
# 25                       Avengers: Infinity War       80.77          8.30
# 26                       Avengers: Infinity War       80.77          8.30
# 27                       Avengers: Infinity War       80.77          8.30
# 28                       Avengers: Infinity War       80.77          8.30
# 29                       Avengers: Infinity War       80.77          8.30
# 30                       Avengers: Infinity War       80.77          8.30
# 31                       Avengers: Infinity War       80.77          8.30
# 32                       Avengers: Infinity War       80.77          8.30
# 33                       Avengers: Infinity War       80.77          8.30
# 35                               Justice League       34.95          6.20
# 36                               Justice League       34.95          6.20
# 37                               Justice League       34.95          6.20
# 38                               Justice League       34.95          6.20
# 39                               Justice League       34.95          6.20
# 40                               Justice League       34.95          6.20
# 41                               Justice League       34.95          6.20
# 42                               Justice League       34.95          6.20
# 43                               Justice League       34.95          6.20
# 44                               Justice League       34.95          6.20
# 45                               Justice League       34.95          6.20
# 46                               Justice League       34.95          6.20
# 47                               Justice League       34.95          6.20
# 48                               Justice League       34.95          6.20
# 49                               Justice League       34.95          6.20
# 50                               Justice League       34.95          6.20
# 51                               Justice League       34.95          6.20
# 52                               Justice League       34.95          6.20
# 53                               Justice League       34.95          6.20
# 54                               Justice League       34.95          6.20
#
#     vote_count production_budget domestic_gross
# 1      8571.00      $410,600,000   $241,063,875
# 2      8571.00      $410,600,000   $241,063,875
# 3      8571.00      $410,600,000   $241,063,875
# 4      8571.00      $410,600,000   $241,063,875
# 5      8571.00      $410,600,000   $241,063,875
# 6      8571.00      $410,600,000   $241,063,875
# 7      8571.00      $410,600,000   $241,063,875
# 8      8571.00      $410,600,000   $241,063,875
# 9      8571.00      $410,600,000   $241,063,875
# 10     8571.00      $410,600,000   $241,063,875
# 12    13457.00      $330,600,000   $459,005,868
# 13    13457.00      $330,600,000   $459,005,868
# 14    13457.00      $330,600,000   $459,005,868
# 15    13457.00      $330,600,000   $459,005,868
# 16    13457.00      $330,600,000   $459,005,868
# 17    13457.00      $330,600,000   $459,005,868
# 18    13457.00      $330,600,000   $459,005,868
# 19    13457.00      $330,600,000   $459,005,868
# 20    13457.00      $330,600,000   $459,005,868
# 21    13457.00      $330,600,000   $459,005,868
# 24    13948.00      $300,000,000   $678,815,482
# 25    13948.00      $300,000,000   $678,815,482
# 26    13948.00      $300,000,000   $678,815,482
# 27    13948.00      $300,000,000   $678,815,482
# 28    13948.00      $300,000,000   $678,815,482
# 29    13948.00      $300,000,000   $678,815,482
# 30    13948.00      $300,000,000   $678,815,482
# 31    13948.00      $300,000,000   $678,815,482
# 32    13948.00      $300,000,000   $678,815,482
# 33    13948.00      $300,000,000   $678,815,482
# 35     7510.00      $300,000,000   $229,024,295
# 36     7510.00      $300,000,000   $229,024,295
# 37     7510.00      $300,000,000   $229,024,295
# 38     7510.00      $300,000,000   $229,024,295
# 39     7510.00      $300,000,000   $229,024,295
# 40     7510.00      $300,000,000   $229,024,295
# 41     7510.00      $300,000,000   $229,024,295
# 42     7510.00      $300,000,000   $229,024,295
# 43     7510.00      $300,000,000   $229,024,295
# 44     7510.00      $300,000,000   $229,024,295
# 45     7510.00      $300,000,000   $229,024,295
# 46     7510.00      $300,000,000   $229,024,295
# 47     7510.00      $300,000,000   $229,024,295
# 48     7510.00      $300,000,000   $229,024,295
# 49     7510.00      $300,000,000   $229,024,295
# 50     7510.00      $300,000,000   $229,024,295
# 51     7510.00      $300,000,000   $229,024,295
# 52     7510.00      $300,000,000   $229,024,295
# 53     7510.00      $300,000,000   $229,024,295
# 54     7510.00      $300,000,000   $229,024,295

# %%
# We see we have several repeating movies (from the talent_list merge), and some null values for popularity

# If we are looking at popularity and votes, we can seee that some titles have null values for these columns
# lets create a table for use specifically when analysing popularity
popularity_non_null = popularity_and_budget.dropna(subset=['popularity'], axis=0)

# and check
popularity_non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32942 entries, 1 to 36913
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     32942 non-null  object
#  1   popularity         32942 non-null  float64
#  2   vote_average       32942 non-null  float64
#  3   vote_count         32942 non-null  float64
#  4   production_budget  32942 non-null  object
#  5   domestic_gross     32942 non-null  object
# dtypes: float64(3), object(3)
# memory usage: 1.8+ MB

# %%
# Lets filter the data to only show unique titles

popularity_non_null.drop_duplicates(subset=['original_title'], inplace=True)

# and check
popularity_non_null.head()
# Out:
#                                  original_title  popularity  vote_average  \
# 1   Pirates of the Caribbean: On Stranger Tides       30.58          6.40
# 12                      Avengers: Age of Ultron       44.38          7.30
# 24                       Avengers: Infinity War       80.77          8.30
# 35                               Justice League       34.95          6.20
# 55                                      Spectre       30.32          6.40
#
#     vote_count production_budget domestic_gross
# 1      8571.00      $410,600,000   $241,063,875
# 12    13457.00      $330,600,000   $459,005,868
# 24    13948.00      $300,000,000   $678,815,482
# 35     7510.00      $300,000,000   $229,024,295
# 55     6719.00      $300,000,000   $200,074,175

# %% [markdown]
# #### That's clean, now we have a subset of titles that have popularity and financials to work with

# %%
# But what if we have a title that has financials but no popularity value?
# Lets create a table of titles with financials and no duplicates to work with as well

# Create table of financials
movie_financials = imdb_titles_merged_df[['original_title', 'production_budget', 'domestic_gross']]

# and drop duplicates
movie_financials.drop_duplicates(subset=['original_title'], inplace=True)

# and check
movie_financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1760 entries, 1 to 36906
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_title     1760 non-null   object
#  1   production_budget  1760 non-null   object
#  2   domestic_gross     1760 non-null   object
# dtypes: object(3)
# memory usage: 55.0+ KB
# <ipython-input-243-d3ad5c758835>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_financials.drop_duplicates(subset=['original_title'], inplace=True)

# %% [markdown]
# #### That's clean too, now we have a subset of all titles and their financials to work with

# %% [markdown]
# #### We have a problem here though, the financials are in dtype=object, which will not allow us to operate on them as numbers, so we will need to somehow transpose the information into number form

# %%
# Lets create a function that will take an object/value and make it into a number

def drop_dollar_sign_and_commas(value):
    """
    This will split the object into a list of characters using the list() function
    Then iterate over the list and drop the $ sign, and remove commas from the list
    - We will use the .remove() method to drop the $, however we will have to use a for loop to remove the commas because .remove() will only remove the first instance, and some values contain more than one comma
    Then after the $ and commas have been removed from the list, we will the .join() method to reconneect the list items into a string
    We then turn the resulting string into a float, save the resulting float back to the original input object and return it
    Now we have float dtypes that allow us to operate on mathematically
    """
    
    value_list = list(value)
    value_list.remove('$')
    for char in value_list:
        if ',' == char:
            value_list.remove(char)
    value_float = float(''.join(value_list))
    value = value_float
    return value

# %%
# lets map this function on our financial columns creating new columns
movie_financials['Budget'] = movie_financials['production_budget'].map(drop_dollar_sign_and_commas)
movie_financials['Domestic Gross'] = movie_financials['domestic_gross'].map(drop_dollar_sign_and_commas)

# and check it
movie_financials.head()
# Out:
# <ipython-input-245-175966651728>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_financials['Budget'] = movie_financials['production_budget'].map(drop_dollar_sign_and_commas)
# <ipython-input-245-175966651728>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_financials['Domestic Gross'] = movie_financials['domestic_gross'].map(drop_dollar_sign_and_commas)
#                                  original_title production_budget  \
# 1   Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 12                      Avengers: Age of Ultron      $330,600,000
# 24                       Avengers: Infinity War      $300,000,000
# 35                               Justice League      $300,000,000
# 55                                      Spectre      $300,000,000
#
#    domestic_gross       Budget  Domestic Gross
# 1    $241,063,875 410600000.00    241063875.00
# 12   $459,005,868 330600000.00    459005868.00
# 24   $678,815,482 300000000.00    678815482.00
# 35   $229,024,295 300000000.00    229024295.00
# 55   $200,074,175 300000000.00    200074175.00

# %%
# lets drop the object columns since we won't need those for the analysis derived on this table
movie_financials.drop(['production_budget', 'domestic_gross'], axis=1, inplace=True)

# and check it
movie_financials.head()
# Out:
# /Users/patrick/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                  original_title       Budget  Domestic Gross
# 1   Pirates of the Caribbean: On Stranger Tides 410600000.00    241063875.00
# 12                      Avengers: Age of Ultron 330600000.00    459005868.00
# 24                       Avengers: Infinity War 300000000.00    678815482.00
# 35                               Justice League 300000000.00    229024295.00
# 55                                      Spectre 300000000.00    200074175.00

# %%
movie_financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1760 entries, 1 to 36906
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  1760 non-null   object
#  1   Budget          1760 non-null   float64
#  2   Domestic Gross  1760 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 55.0+ KB

# %%
# 5698 movies is a lot to work with
# Lets wittle this down to the top 30 grossing movies
top_50_grossing_movies = movie_financials.sort_values(by='Domestic Gross', ascending=False).head(30)

top_50_grossing_movies
# Out:
#                              original_title       Budget  Domestic Gross
# 493                           Black Panther 200000000.00    700059566.00
# 24                   Avengers: Infinity War 300000000.00    678815482.00
# 261                          Jurassic World 215000000.00    652270625.00
# 199                            The Avengers 225000000.00    623279547.00
# 514                           Incredibles 2 200000000.00    608581744.00
# 1437                   Beauty and the Beast 160000000.00    504014165.00
# 526                            Finding Dory 200000000.00    486295561.00
# 12                  Avengers: Age of Ultron 330600000.00    459005868.00
# 75                    The Dark Knight Rises 275000000.00    448139099.00
# 2217        The Hunger Games: Catching Fire 130000000.00    424668047.00
# 6188                          The Lion King  79300000.00    421785283.00
# 1258         Jurassic World: Fallen Kingdom 170000000.00    417719760.00
# 536                             Toy Story 3 200000000.00    415004880.00
# 1656                           Wonder Woman 150000000.00    412563408.00
# 126              Captain America: Civil War 250000000.00    408084349.00
# 5956                       The Hunger Games  80000000.00    408010692.00
# 5369         Jumanji: Welcome to the Jungle  90000000.00    404508916.00
# 1698                                 Frozen 150000000.00    400738009.00
# 6274                The Secret Life of Pets  75000000.00    368384330.00
# 6261                        Despicable Me 2  76000000.00    368065385.00
# 1014                        The Jungle Book 175000000.00    364001123.00
# 8063                               Deadpool  58000000.00    363070709.00
# 1052                             Inside Out 175000000.00    356461711.00
# 713          Transformers: Dark of the Moon 195000000.00    352390543.00
# 8073                        American Sniper  58000000.00    350126372.00
# 1738                               Zootopia 150000000.00    341268248.00
# 4046  The Hunger Games: Mockingjay - Part 1 125000000.00    337135885.00
# 6639                                Minions  74000000.00    336045770.00
# 1517                                Aquaman 160000000.00    335061807.00
# 1162                 Spider-Man: Homecoming 175000000.00    334201140.00

# %% [markdown]
# ### lets visualize this based on gross and budget stacked, which will allow us to see the profit made
#
# #### Currency function code generously donated from [dataxizpyr](https://datavizpyr.com/add-dollar-sign-on-axis-ticks-in-matplotlib/)

# %%
# Create a function to convert ticks to currency

def currency(x, pos):
    """
    This function will format a tick of float type to currency
    The two args are the value and tick position
    """
    if x >= 1e6:
        s = '${:1.0f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}'.format(x*1e-3)
    return s

# Now lets create the plot
fig, ax = plt.subplots()
fig.set_size_inches(20, 20)
fig.set_facecolor('lawngreen')
ax.set_facecolor('black')
ax.barh(top_50_grossing_movies['original_title'], width=top_50_grossing_movies['Domestic Gross'], height=0.5)
ax.barh(top_50_grossing_movies['original_title'], width=top_50_grossing_movies['Budget'], height=0.5)
ax.set_xlabel('Dollars', font='Andale Mono', fontsize=30, labelpad=15)
ax.set_ylabel('Movie', rotation=30, font='Andale Mono', fontsize=30, labelpad=10)
ax.set_title('Gross Profit', font='Andale Mono', fontsize=40, weight='bold', loc="center", pad=0)
labels = 'Domestic Gross', 'Budget'
ax.legend(labels, fontsize=20, facecolor='lawngreen', loc=7)
plt.xticks(font='Andale Mono', fontsize=24, weight='bold')
plt.yticks(font='Andale Mono', fontsize=20, weight='bold')
ax.invert_yaxis()
plt.ticklabel_format(axis='x', style='plain')
ax.xaxis.set_major_formatter(currency)

# %%
# Lets check out the popularity of movies
